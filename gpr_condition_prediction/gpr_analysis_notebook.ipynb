# %%
import os
import pandas as pd
import numpy as np
from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic, ExpSineSquared, WhiteKernel
from gpr_predictions import Halogenation
import warnings

warnings.filterwarnings("ignore") # Ignore convergence warnings when running the GPR models

# %% [markdown]
# Data imports

# %%
data_yield = pd.read_csv('hte_halogenation_yields_for_gpr.csv', index_col = 'Unnamed: 0')
data_conv = pd.read_csv('hte_halogenation_conversions_for_gpr.csv', index_col = 'Unnamed: 0')

# Seperate the yield data into the different halogenations
#chloro_yield = data_yield[data_yield['Unnamed: 0')].str.contains('chloro')]
#bromo_yield = data_yield[data_yield['Unnamed: 0')].str.contains('bromo')]
#iodo_yield = data_yield[data_yield['Unnamed: 0')].str.contains('iodo')]

# Seperate the conversion data into the different halogenations
#chloro_conv = data_conv[data_conv['Unnamed: 0')].str.contains('chloro')]
#bromo_conv = data_conv[data_conv['Unnamed: 0')].str.contains('bromo')]
#iodo_conv = data_conv[data_conv['Unnamed: 0')].str.contains('iodo')]

# %% [markdown]
# # GPR Predictions for Stage 2 halogenation conditions prediction
# This notebook contains original code use to determine optimum acidic conditions for the late stage halogenation of pharmaceuticals. This uses stage 2 data generated from screening a series of halogenations against 0 - 25 TFA equivalents, outputting information about the optimum conditions determined using an optimal kernel, as well as yield and conversion predicitions, at two different length scales.

# %% [markdown]
# Function for kernel screening using the GPR halogenation class

# %%
def gpr_kernel_screening(data_yield, 
                         data_conv, 
                         kernels,   
                         ):
    
    # Initialise dataframe to store condition prediction information
    optimum_condition_df = pd.DataFrame(columns=['substrate',
                                                 'reagent',
                                                 'pred_opt_tfa', 
                                                'pred_opt_yield(%)',
                                                'pred_opt_stddev(%)',
                                                'pred_opt_conv(%)',
                                                'pred_opt_stddev_conv(%)',
                                                'kernel_yield',
                                                'kernel_yield_loo_mae(%)',
                                                'kernel_conv',
                                                'kernel_conv_loo_mae(%)',
                                            ]) 
    
    # Initialise dataframe to store the optimum conditions and kernel information
    gpr_pred_df_yield = pd.DataFrame(columns=np.linspace(0, 25, 1000), dtype=object)
    gpr_pred_df_conv = pd.DataFrame(columns=np.linspace(0, 25, 1000), dtype=object)
    
    #gpr_pred_df_yield_stddev = pd.DataFrame(columns=np.linspace(0, 25, 1000))
    #gpr_pred_df_conv_stddev = pd.DataFrame(columns=np.linspace(0, 25, 1000))


    acid_exp = [float(x) for x in data_yield.columns]
    #print(acid_exp)

    # Loop through the different halogenations
    for product_y, product_c in zip(data_yield.itertuples(index = True), data_conv.itertuples(index = True)):
        
        # Get the product name and extract the reagent and starting material
        product = product_y[0]
        starting_material = product.split('-')[-1]
        suffix = product.split('-')[-2]
        if suffix == 'chloro':
            reagent = "Palau'chlor"
        elif suffix == 'bromo':
            reagent = "N-bromosuccinimide"
        elif suffix == 'iodo':
            reagent = "N-iodosuccinimide"
        else:
            reagent = 'Unknown'
        
        print(f'Predicting conditions for the formation of {product_y[0]} with {starting_material} and {reagent}...')

        # Get the yield and conversion data
        yield_data = product_y[1:]
        #print(f'Yield data for {product}: {yield_data}')
        conv_data = product_c[1:]
        
        combined_data = np.column_stack([acid_exp, yield_data, conv_data]) # Combine the yield and conversion data with the acid equiv data
        #print(combined_data)
        #print(f'Predicting conditions for the fomration of {product}...')

        # Initialise the Halogenation class
        halogenation = Halogenation(starting_material, reagent, combined_data)
        
        # Kernel screening
        for kernel_label, kernel in kernels.items():
            halogenation.gprcalculate(kernel, dset = 'both', kernelname = kernel_label) # Run all kernels specified prior
        
        # Get the best kernels (lowest MAE) for yield and conversion
        best_kernel_yield = halogenation.best_model_yield()
        best_kernel_conv = halogenation.best_model_conv()

        # Determine the optimum conditions for the best kernel
        optimum_condition = halogenation.pickoptimum(yield_kernel = best_kernel_yield, conv_kernel = best_kernel_conv) # Get the optimum conditions for the best kernel

        #print(f'TFA equiv: {optimum_condition[0]}, Predicted yield: {optimum_condition[1]}%, Yield std: {optimum_condition[2]}%, Predicted conversion: {optimum_condition[3]}%, Conversion std: {optimum_condition[4]}%')
        
        # Store the optimum conditions and kernel information
        optimum_condition_df.loc[product] = [starting_material,
                                             reagent,
                                             optimum_condition[0], 
                                             optimum_condition[1],
                                             optimum_condition[2],
                                             optimum_condition[3],
                                             optimum_condition[4],
                                             best_kernel_yield,
                                             halogenation.yieldoutputs[best_kernel_yield]['mae'],
                                             best_kernel_conv,
                                             halogenation.convoutputs[best_kernel_conv]['mae'],
                                          ]


        # Store the best kernel predicitions for plotting
        best_predictions_yield = halogenation.yieldoutputs[best_kernel_yield]['prediction'][:,1:] # Output continuous predictions for the best kernel [yield, stddev]
        best_predicitions_conv = halogenation.convoutputs[best_kernel_conv]['prediction'][:,1:] # Output continuous predictions for the best kernel [conversion, stddev]
        
        #print(best_predictions_yield)
        #print(best_predicitions_conv)
        #print(len(best_predictions_yield))
        #print(len(best_predicitions_conv))

        gpr_pred_df_yield.loc[product] = list(best_predictions_yield) # Append to yield df specified as an argument
        gpr_pred_df_conv.loc[product] = list(best_predicitions_conv) # Append to conversion df specified as an argument


    return optimum_condition_df, gpr_pred_df_yield, gpr_pred_df_conv

# %% [markdown]
# Function to generate kernels for screening

# %%
# Kernels for screening - RBF, Matern (nu = 3/2), Matern (nu = 5/2) with WhiteKernel to model noise
def get_kernels(ls_bounds):
    return {'RBF': 1.0 * RBF(length_scale=1e0, length_scale_bounds=ls_bounds)+ WhiteKernel(noise_level=1e0, noise_level_bounds=ls_bounds),
          'Matern (nu = 3/2)': 1.0 * Matern(length_scale=1e0, length_scale_bounds=ls_bounds, nu=3/2)+ WhiteKernel(noise_level=1e0, noise_level_bounds=ls_bounds),
          'Matern (nu = 5/2)': 1.0 * Matern(length_scale=1e0, length_scale_bounds=ls_bounds, nu=5/2)+ WhiteKernel(noise_level=1e0, noise_level_bounds=ls_bounds),
          # 'Rational quadratic (RQ)': 1.0 * RationalQuadratic(length_scale=1e0, length_scale_bounds=ls_bounds),+ WhiteKernel(noise_level=1e0, noise_level_bounds=ls_bounds),
          # UNCOMMENT THE ABOVE LINES TO USE OTHER KERNELS. Tended to result in overfitting for many of the datasets used in this study
          }

# %% [markdown]
# Running the models and getting our predictions

# %%
#Screen kernels over 2 length scales. Compare the best from both length scales an choose based on inspection of the predictions
low_ls_kernels = get_kernels((1e-1, 1e1)) # Sometime a tendency to overfit with low length scales
high_ls_kernels = get_kernels((1e0, 1e2)) # Sometimes a tendency to underfit with high length scales

# Run the models!
optimum_condition_df_lowls, gpr_pred_df_yield_lowls, gpr_pred_df_conv_lowls = gpr_kernel_screening(data_yield, data_conv, low_ls_kernels)
optimum_condition_df_highls, gpr_pred_df_yield_highls, gpr_pred_df_conv_highls = gpr_kernel_screening(data_yield, data_conv, high_ls_kernels)
# Out:
# Predicting conditions for the formation of bromo-Bifonazole with Bifonazole and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Camptothecin with Camptothecin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ciprofloxacin with Ciprofloxacin and N-bromosuccinimide...
# Predicting conditions for the formation of 4-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of 6-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ketanserin with Ketanserin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Lidocaine with Lidocaine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Mizolastine with Mizolastine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Nevirapine with Nevirapine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Palbociclib with Palbociclib and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Paracetamol with Paracetamol and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Quinine with Quinine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Risperidone with Risperidone and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Salicin with Salicin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Yohimbine with Yohimbine and N-bromosuccinimide...
# Predicting conditions for the formation of chloro-Bifonazole with Bifonazole and Palau'chlor...
# Predicting conditions for the formation of chloro-Boscalid  with Boscalid  and Palau'chlor...
# Predicting conditions for the formation of chloro-Caffeine with Caffeine and Palau'chlor...
# Predicting conditions for the formation of chloro-Camptothecin with Camptothecin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ciprofloxacin with Ciprofloxacin and Palau'chlor...
# Predicting conditions for the formation of chloro-Griseofulvin with Griseofulvin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ibuprofen with Ibuprofen and Palau'chlor...
# Predicting conditions for the formation of chloro-Mizolastine with Mizolastine and Palau'chlor...
# Predicting conditions for the formation of chloro-Palbociclib with Palbociclib and Palau'chlor...
# Predicting conditions for the formation of chloro-Paracetamol with Paracetamol and Palau'chlor...
# Predicting conditions for the formation of chloro-Quinine with Quinine and Palau'chlor...
# Predicting conditions for the formation of chloro-Risperidone with Risperidone and Palau'chlor...
# Predicting conditions for the formation of chloro-Ritonavir with Ritonavir and Palau'chlor...
# Predicting conditions for the formation of iodo-Griseofulvin with Griseofulvin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroquinine with Hydroquinine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroxychloroquine with Hydroxychloroquine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ibuprofen with Ibuprofen and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Indomethacin with Indomethacin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ketanserin with Ketanserin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Lidocaine with Lidocaine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Palbociclib with Palbociclib and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Paracetamol with Paracetamol and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Risperidone with Risperidone and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ritonavir with Ritonavir and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Salicin with Salicin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Yohimbine with Yohimbine and N-iodosuccinimide...
# Predicting conditions for the formation of bromo-Bifonazole with Bifonazole and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Camptothecin with Camptothecin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ciprofloxacin with Ciprofloxacin and N-bromosuccinimide...
# Predicting conditions for the formation of 4-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of 6-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ketanserin with Ketanserin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Lidocaine with Lidocaine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Mizolastine with Mizolastine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Nevirapine with Nevirapine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Palbociclib with Palbociclib and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Paracetamol with Paracetamol and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Quinine with Quinine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Risperidone with Risperidone and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Salicin with Salicin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Yohimbine with Yohimbine and N-bromosuccinimide...
# Predicting conditions for the formation of chloro-Bifonazole with Bifonazole and Palau'chlor...
# Predicting conditions for the formation of chloro-Boscalid  with Boscalid  and Palau'chlor...
# Predicting conditions for the formation of chloro-Caffeine with Caffeine and Palau'chlor...
# Predicting conditions for the formation of chloro-Camptothecin with Camptothecin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ciprofloxacin with Ciprofloxacin and Palau'chlor...
# Predicting conditions for the formation of chloro-Griseofulvin with Griseofulvin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ibuprofen with Ibuprofen and Palau'chlor...
# Predicting conditions for the formation of chloro-Mizolastine with Mizolastine and Palau'chlor...
# Predicting conditions for the formation of chloro-Palbociclib with Palbociclib and Palau'chlor...
# Predicting conditions for the formation of chloro-Paracetamol with Paracetamol and Palau'chlor...
# Predicting conditions for the formation of chloro-Quinine with Quinine and Palau'chlor...
# Predicting conditions for the formation of chloro-Risperidone with Risperidone and Palau'chlor...
# Predicting conditions for the formation of chloro-Ritonavir with Ritonavir and Palau'chlor...
# Predicting conditions for the formation of iodo-Griseofulvin with Griseofulvin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroquinine with Hydroquinine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroxychloroquine with Hydroxychloroquine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ibuprofen with Ibuprofen and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Indomethacin with Indomethacin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ketanserin with Ketanserin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Lidocaine with Lidocaine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Palbociclib with Palbociclib and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Paracetamol with Paracetamol and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Risperidone with Risperidone and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ritonavir with Ritonavir and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Salicin with Salicin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Yohimbine with Yohimbine and N-iodosuccinimide...

# %%
optimum_condition_df_lowls
# Out:
#                                   substrate             reagent  pred_opt_tfa  \
# bromo-Bifonazole                 Bifonazole  N-bromosuccinimide      2.802803
# bromo-Camptothecin             Camptothecin  N-bromosuccinimide      1.376376
# bromo-Ciprofloxacin           Ciprofloxacin  N-bromosuccinimide     24.824825
# 4-bromo-Indomethacin           Indomethacin  N-bromosuccinimide      0.000000
# 6-bromo-Indomethacin           Indomethacin  N-bromosuccinimide     17.067067
# bromo-Ketanserin                 Ketanserin  N-bromosuccinimide      3.828829
# bromo-Lidocaine                   Lidocaine  N-bromosuccinimide      2.352352
# bromo-Mizolastine               Mizolastine  N-bromosuccinimide     10.960961
# bromo-Nevirapine                 Nevirapine  N-bromosuccinimide      0.000000
# bromo-Palbociclib               Palbociclib  N-bromosuccinimide     11.136136
# bromo-Paracetamol               Paracetamol  N-bromosuccinimide      0.000000
# bromo-Quinine                       Quinine  N-bromosuccinimide      2.002002
# bromo-Risperidone               Risperidone  N-bromosuccinimide      4.329329
# bromo-Salicin                       Salicin  N-bromosuccinimide      0.000000
# bromo-Yohimbine                   Yohimbine  N-bromosuccinimide     15.715716
# chloro-Bifonazole                Bifonazole         Palau'chlor      3.128128
# chloro-Boscalid                   Boscalid          Palau'chlor      1.451451
# chloro-Caffeine                    Caffeine         Palau'chlor      0.000000
# chloro-Camptothecin            Camptothecin         Palau'chlor      8.008008
# chloro-Ciprofloxacin          Ciprofloxacin         Palau'chlor      2.802803
# chloro-Griseofulvin            Griseofulvin         Palau'chlor      1.626627
# chloro-Ibuprofen                  Ibuprofen         Palau'chlor      1.401401
# chloro-Mizolastine              Mizolastine         Palau'chlor      2.077077
# chloro-Palbociclib              Palbociclib         Palau'chlor      4.779780
# chloro-Paracetamol              Paracetamol         Palau'chlor     21.071071
# chloro-Quinine                      Quinine         Palau'chlor      1.576577
# chloro-Risperidone              Risperidone         Palau'chlor     10.060060
# chloro-Ritonavir                  Ritonavir         Palau'chlor      1.076076
# iodo-Griseofulvin              Griseofulvin   N-iodosuccinimide      3.528529
# iodo-Hydroquinine              Hydroquinine   N-iodosuccinimide     25.000000
# iodo-Hydroxychloroquine  Hydroxychloroquine   N-iodosuccinimide     23.323323
# iodo-Ibuprofen                    Ibuprofen   N-iodosuccinimide     25.000000
# iodo-Indomethacin              Indomethacin   N-iodosuccinimide      5.455455
# iodo-Ketanserin                  Ketanserin   N-iodosuccinimide      9.684685
# iodo-Lidocaine                    Lidocaine   N-iodosuccinimide     14.889890
# iodo-Palbociclib                Palbociclib   N-iodosuccinimide     10.010010
# iodo-Paracetamol                Paracetamol   N-iodosuccinimide      4.279279
# iodo-Risperidone                Risperidone   N-iodosuccinimide     25.000000
# iodo-Ritonavir                    Ritonavir   N-iodosuccinimide      1.576577
# iodo-Salicin                        Salicin   N-iodosuccinimide      0.000000
# iodo-Yohimbine                    Yohimbine   N-iodosuccinimide      2.652653
#
#                          pred_opt_yield(%)  pred_opt_stddev(%)  \
# bromo-Bifonazole                121.323884           26.341152
# bromo-Camptothecin              106.621300            6.439019
# bromo-Ciprofloxacin             126.102268            7.517618
# 4-bromo-Indomethacin             78.103974            2.749370
# 6-bromo-Indomethacin             52.161459            1.745727
# bromo-Ketanserin                 73.018264            4.611773
# bromo-Lidocaine                  94.820764           16.617800
# bromo-Mizolastine               109.699623            3.789050
# bromo-Nevirapine                 13.026350            1.681617
# bromo-Palbociclib               105.061489           16.245425
# bromo-Paracetamol                75.324659            4.227379
# bromo-Quinine                    75.987733            0.449824
# bromo-Risperidone                21.755492            1.668429
# bromo-Salicin                   116.071190            4.455907
# bromo-Yohimbine                  50.156381            5.541119
# chloro-Bifonazole                55.918117           10.917069
# chloro-Boscalid                  67.135686            6.774375
# chloro-Caffeine                  24.956068            0.446121
# chloro-Camptothecin              88.496520           22.015080
# chloro-Ciprofloxacin             87.846815            7.727658
# chloro-Griseofulvin              72.706727            4.725742
# chloro-Ibuprofen                103.921855            8.387984
# chloro-Mizolastine               78.093675            4.705963
# chloro-Palbociclib              115.353547           13.398951
# chloro-Paracetamol               39.314535            4.803707
# chloro-Quinine                  113.361696            1.504417
# chloro-Risperidone               69.792952            4.511466
# chloro-Ritonavir                 69.223393            4.839999
# iodo-Griseofulvin                26.149009            4.067486
# iodo-Hydroquinine                13.531735            2.785669
# iodo-Hydroxychloroquine          96.301500           12.559298
# iodo-Ibuprofen                   52.808806            2.354482
# iodo-Indomethacin                93.094501           13.988638
# iodo-Ketanserin                 118.120756            8.262844
# iodo-Lidocaine                  125.938679            5.511160
# iodo-Palbociclib                 30.756699            2.561679
# iodo-Paracetamol                 53.107986            4.478137
# iodo-Risperidone                 28.983315            0.447110
# iodo-Ritonavir                  111.395232            1.742917
# iodo-Salicin                     81.252537            4.460570
# iodo-Yohimbine                   93.443379           14.423915
#
#                          pred_opt_conv(%)  pred_opt_stddev_conv(%)  \
# bromo-Bifonazole               109.637529                26.166335
# bromo-Camptothecin              86.373954                 4.997484
# bromo-Ciprofloxacin             72.445175                 7.414901
# 4-bromo-Indomethacin            64.383664                 1.229269
# 6-bromo-Indomethacin            40.917766                 1.158144
# bromo-Ketanserin                56.613407                 4.304928
# bromo-Lidocaine                 70.477746                11.625458
# bromo-Mizolastine               90.238223                 3.500560
# bromo-Nevirapine                15.638873                 1.373096
# bromo-Palbociclib               88.999995                18.048326
# bromo-Paracetamol               72.928670                 0.441704
# bromo-Quinine                   64.983537                 0.450668
# bromo-Risperidone               18.212328                 0.949543
# bromo-Salicin                   89.298917                 4.280528
# bromo-Yohimbine                 50.396498                 8.269660
# chloro-Bifonazole               51.250968                10.780907
# chloro-Boscalid                 61.270771                 6.640489
# chloro-Caffeine                 29.968640                 0.446146
# chloro-Camptothecin             70.530699                41.499122
# chloro-Ciprofloxacin            84.989800                 7.022558
# chloro-Griseofulvin             65.854827                 4.552141
# chloro-Ibuprofen                79.171496                 6.426123
# chloro-Mizolastine              94.383719                 4.530573
# chloro-Palbociclib              93.195011                 9.806736
# chloro-Paracetamol              48.933002                 3.572633
# chloro-Quinine                 101.753022                 1.105806
# chloro-Risperidone              49.838377                 4.476835
# chloro-Ritonavir                61.751336                 1.776713
# iodo-Griseofulvin               26.544929                 4.213995
# iodo-Hydroquinine               10.658470                 2.257977
# iodo-Hydroxychloroquine         85.518715                11.565318
# iodo-Ibuprofen                  90.606921                 4.404464
# iodo-Indomethacin               79.504851                 9.784191
# iodo-Ketanserin                 79.147349                 6.219091
# iodo-Lidocaine                  87.026381                 4.821071
# iodo-Palbociclib                17.308212                 4.423572
# iodo-Paracetamol                53.270766                 4.588563
# iodo-Risperidone                20.978643                 0.447059
# iodo-Ritonavir                  75.805902                 6.461968
# iodo-Salicin                    61.649158                 4.434868
# iodo-Yohimbine                 104.545578                16.761325
#
#                               kernel_yield  kernel_yield_loo_mae(%)  \
# bromo-Bifonazole         Matern (nu = 3/2)                65.778879
# bromo-Camptothecin       Matern (nu = 3/2)                17.465633
# bromo-Ciprofloxacin      Matern (nu = 3/2)                41.525851
# 4-bromo-Indomethacin     Matern (nu = 5/2)                 1.635365
# 6-bromo-Indomethacin     Matern (nu = 3/2)                 3.346906
# bromo-Ketanserin         Matern (nu = 3/2)                10.598046
# bromo-Lidocaine          Matern (nu = 3/2)                33.328170
# bromo-Mizolastine        Matern (nu = 3/2)                 4.782416
# bromo-Nevirapine                       RBF                 1.229007
# bromo-Palbociclib        Matern (nu = 3/2)                24.013185
# bromo-Paracetamol        Matern (nu = 3/2)                 9.432056
# bromo-Quinine            Matern (nu = 5/2)                11.622069
# bromo-Risperidone        Matern (nu = 5/2)                 4.146691
# bromo-Salicin            Matern (nu = 3/2)                20.443488
# bromo-Yohimbine          Matern (nu = 3/2)                11.013453
# chloro-Bifonazole        Matern (nu = 3/2)                26.905657
# chloro-Boscalid          Matern (nu = 3/2)                35.807103
# chloro-Caffeine          Matern (nu = 3/2)                 3.023142
# chloro-Camptothecin      Matern (nu = 3/2)                29.088925
# chloro-Ciprofloxacin     Matern (nu = 3/2)                17.574110
# chloro-Griseofulvin      Matern (nu = 3/2)                25.061640
# chloro-Ibuprofen         Matern (nu = 3/2)                48.583410
# chloro-Mizolastine       Matern (nu = 3/2)                27.852007
# chloro-Palbociclib       Matern (nu = 3/2)                36.187285
# chloro-Paracetamol       Matern (nu = 3/2)                 4.540387
# chloro-Quinine                         RBF                12.726449
# chloro-Risperidone       Matern (nu = 3/2)                15.425278
# chloro-Ritonavir         Matern (nu = 5/2)                 9.486915
# iodo-Griseofulvin        Matern (nu = 3/2)                 7.956119
# iodo-Hydroquinine        Matern (nu = 5/2)                 2.352806
# iodo-Hydroxychloroquine  Matern (nu = 3/2)                13.566816
# iodo-Ibuprofen           Matern (nu = 5/2)                 7.303974
# iodo-Indomethacin        Matern (nu = 3/2)                37.953709
# iodo-Ketanserin          Matern (nu = 3/2)                34.898546
# iodo-Lidocaine           Matern (nu = 3/2)                39.490308
# iodo-Palbociclib                       RBF                17.406733
# iodo-Paracetamol         Matern (nu = 3/2)                12.229630
# iodo-Risperidone         Matern (nu = 3/2)                 3.871273
# iodo-Ritonavir                         RBF                27.816033
# iodo-Salicin             Matern (nu = 3/2)                26.794766
# iodo-Yohimbine           Matern (nu = 3/2)                33.115987
#
#                                kernel_conv  kernel_conv_loo_mae(%)
# bromo-Bifonazole         Matern (nu = 3/2)               55.828413
# bromo-Camptothecin       Matern (nu = 3/2)               12.997788
# bromo-Ciprofloxacin      Matern (nu = 3/2)               36.148670
# 4-bromo-Indomethacin     Matern (nu = 3/2)                2.040484
# 6-bromo-Indomethacin     Matern (nu = 3/2)                1.540808
# bromo-Ketanserin         Matern (nu = 3/2)                6.218079
# bromo-Lidocaine          Matern (nu = 3/2)               25.900566
# bromo-Mizolastine        Matern (nu = 5/2)                4.578329
# bromo-Nevirapine                       RBF                1.359206
# bromo-Palbociclib        Matern (nu = 3/2)               24.408109
# bromo-Paracetamol        Matern (nu = 3/2)                4.472427
# bromo-Quinine            Matern (nu = 3/2)               10.790404
# bromo-Risperidone                      RBF                3.250339
# bromo-Salicin            Matern (nu = 3/2)                8.555337
# bromo-Yohimbine          Matern (nu = 3/2)               13.433814
# chloro-Bifonazole        Matern (nu = 3/2)               24.895202
# chloro-Boscalid          Matern (nu = 3/2)               33.323306
# chloro-Caffeine          Matern (nu = 3/2)                3.087815
# chloro-Camptothecin      Matern (nu = 3/2)               44.084526
# chloro-Ciprofloxacin     Matern (nu = 3/2)               16.361439
# chloro-Griseofulvin      Matern (nu = 3/2)               20.889101
# chloro-Ibuprofen         Matern (nu = 3/2)               35.806579
# chloro-Mizolastine       Matern (nu = 3/2)               22.167521
# chloro-Palbociclib       Matern (nu = 3/2)               26.780643
# chloro-Paracetamol                     RBF                2.947040
# chloro-Quinine                         RBF               11.698327
# chloro-Risperidone       Matern (nu = 3/2)               11.311370
# chloro-Ritonavir         Matern (nu = 5/2)               10.220328
# iodo-Griseofulvin        Matern (nu = 3/2)               10.051973
# iodo-Hydroquinine                      RBF                1.905881
# iodo-Hydroxychloroquine  Matern (nu = 3/2)               13.607236
# iodo-Ibuprofen           Matern (nu = 5/2)               11.943568
# iodo-Indomethacin        Matern (nu = 3/2)               29.386016
# iodo-Ketanserin          Matern (nu = 3/2)               23.536535
# iodo-Lidocaine           Matern (nu = 3/2)               24.469353
# iodo-Palbociclib         Matern (nu = 3/2)               12.289909
# iodo-Paracetamol         Matern (nu = 3/2)               14.450274
# iodo-Risperidone         Matern (nu = 3/2)                3.525509
# iodo-Ritonavir           Matern (nu = 5/2)               27.920843
# iodo-Salicin             Matern (nu = 3/2)               26.903211
# iodo-Yohimbine           Matern (nu = 3/2)               38.465222

# %% [markdown]
# Exporting the results for later use...

# %%
# Export the results to csvs
os.makedirs('gpr_results', exist_ok=True)
optimum_condition_df_lowls.to_csv('gpr_results/optimum_conditions_lowls.csv') # Optimum conditions using the lower length scale kernels (0.1 - 10)
gpr_pred_df_yield_lowls.to_csv('gpr_results/gpr_predictions_yield_lowls.csv') # GPR predictions for yield using the lower length scale kernels (0.1 - 10)
gpr_pred_df_conv_lowls.to_csv('gpr_results/gpr_predictions_conv_lowls.csv') # GPR predictions for conversion using the lower length scale kernels (0.1 - 10)

optimum_condition_df_highls.to_csv('gpr_results/optimum_conditions_highls.csv') # Optimum conditions using the higher length scale kernels (1 - 100)
gpr_pred_df_yield_highls.to_csv('gpr_results/gpr_predictions_yield_highls.csv') # GPR predictions for yield using the higher length scale kernels (1 - 100)
gpr_pred_df_conv_highls.to_csv('gpr_results/gpr_predictions_conv_highls.csv') # GPR predictions for conversion using the higher length scale kernels (1 - 100)

# %% [markdown]
# ## Cubic Spline Benchmarking

# %%
def spline_screening(data_yield):
    
    spline_pred_df_yield = pd.DataFrame(columns=np.linspace(0, 25, 1000), dtype=object)
    maes = []
    acid_exp = [float(x) for x in data_yield.columns]

    for product_y in data_yield.itertuples(index = True):
        # Get the product name and extract the reagent and starting material
        product = product_y[0]
        starting_material = product.split('-')[-1]
        suffix = product.split('-')[-2]
        if suffix == 'chloro':
            reagent = "Palau'chlor"
        elif suffix == 'bromo':
            reagent = "N-bromosuccinimide"
        elif suffix == 'iodo':
            reagent = "N-iodosuccinimide"
        else:
            reagent = 'Unknown'
        
        print(f'Predicting conditions for the formation of {product_y[0]} with {starting_material} and {reagent}...')

        # Get the yield data
        yield_data = product_y[1:]
        
        combined_data = np.column_stack([acid_exp, yield_data]) # Combine the yielddata with the acid equiv data
        #print(combined_data)
        #print(f'Predicting conditions for the fomration of {product}...')

        # Initialise the Halogenation class
        halogenation = Halogenation(starting_material, reagent, combined_data)

        # Fit a cubic spline to the yield data
        _, y_pred, mae = halogenation.spline_benchmark()

        maes.append(mae)

        spline_pred_df_yield.loc[product] = list(y_pred) # Append to yield df specified as an argument
    
    spline_pred_df_yield['mae'] = maes # Add the MAE values to the dataframe

    return spline_pred_df_yield

# %%
# Run spline screening
spline_pred_df_yield = spline_screening(data_yield)
# Out:
# Predicting conditions for the formation of bromo-Bifonazole with Bifonazole and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Camptothecin with Camptothecin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ciprofloxacin with Ciprofloxacin and N-bromosuccinimide...
# Predicting conditions for the formation of 4-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of 6-bromo-Indomethacin with Indomethacin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Ketanserin with Ketanserin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Lidocaine with Lidocaine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Mizolastine with Mizolastine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Nevirapine with Nevirapine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Palbociclib with Palbociclib and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Paracetamol with Paracetamol and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Quinine with Quinine and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Risperidone with Risperidone and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Salicin with Salicin and N-bromosuccinimide...
# Predicting conditions for the formation of bromo-Yohimbine with Yohimbine and N-bromosuccinimide...
# Predicting conditions for the formation of chloro-Bifonazole with Bifonazole and Palau'chlor...
# Predicting conditions for the formation of chloro-Boscalid  with Boscalid  and Palau'chlor...
# Predicting conditions for the formation of chloro-Caffeine with Caffeine and Palau'chlor...
# Predicting conditions for the formation of chloro-Camptothecin with Camptothecin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ciprofloxacin with Ciprofloxacin and Palau'chlor...
# Predicting conditions for the formation of chloro-Griseofulvin with Griseofulvin and Palau'chlor...
# Predicting conditions for the formation of chloro-Ibuprofen with Ibuprofen and Palau'chlor...
# Predicting conditions for the formation of chloro-Mizolastine with Mizolastine and Palau'chlor...
# Predicting conditions for the formation of chloro-Palbociclib with Palbociclib and Palau'chlor...
# Predicting conditions for the formation of chloro-Paracetamol with Paracetamol and Palau'chlor...
# Predicting conditions for the formation of chloro-Quinine with Quinine and Palau'chlor...
# Predicting conditions for the formation of chloro-Risperidone with Risperidone and Palau'chlor...
# Predicting conditions for the formation of chloro-Ritonavir with Ritonavir and Palau'chlor...
# Predicting conditions for the formation of iodo-Griseofulvin with Griseofulvin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroquinine with Hydroquinine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Hydroxychloroquine with Hydroxychloroquine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ibuprofen with Ibuprofen and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Indomethacin with Indomethacin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ketanserin with Ketanserin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Lidocaine with Lidocaine and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Palbociclib with Palbociclib and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Paracetamol with Paracetamol and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Risperidone with Risperidone and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Ritonavir with Ritonavir and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Salicin with Salicin and N-iodosuccinimide...
# Predicting conditions for the formation of iodo-Yohimbine with Yohimbine and N-iodosuccinimide...

# %%
spline_pred_df_yield.to_csv('gpr_results/spline_predictions_yield.csv') # Spline predictions for yield
